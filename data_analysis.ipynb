# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statistics as st
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\user\OneDrive\Desktop\Engage\pre_processed_data.csv')

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df.head()
# Out:
#    Unnamed: 0  Make      Model  Variant  Ex-Showroom_Price  Displacement  \
# 0           0  Tata  Nano Genx       Xt           292667.0         624.0
# 1           1  Tata  Nano Genx       Xe           236447.0         624.0
# 2           2  Tata  Nano Genx  Emax Xm           296661.0         624.0
# 3           3  Tata  Nano Genx      Xta           334768.0         624.0
# 4           4  Tata  Nano Genx       Xm           272223.0         624.0
#
#    Kerb_Weight  Cylinders Emission_Norm  Fuel_Tank_Capacity Fuel_Type  \
# 0        660.0        2.0         BS IV                24.0    Petrol
# 1        725.0        2.0         BS IV                24.0    Petrol
# 2        710.0        2.0         BS IV                15.0       CNG
# 3        725.0        2.0         BS IV                24.0    Petrol
# 4        725.0        2.0         BS IV                24.0    Petrol
#
#    Body_Type  Doors  ARAI_Certified_Mileage Gears  Ground_Clearance  \
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df=df.drop(columns=['Unnamed: 0'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1276 entries, 0 to 1275
# Data columns (total 45 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Make                    1276 non-null   object
#  1   Model                   1276 non-null   object
#  2   Variant                 1276 non-null   object
#  3   Ex-Showroom_Price       1276 non-null   float64
#  4   Displacement            1276 non-null   float64
#  5   Kerb_Weight             1276 non-null   float64
#  6   Cylinders               1276 non-null   float64
#  7   Emission_Norm           1276 non-null   object
#  8   Fuel_Tank_Capacity      1276 non-null   float64
#  9   Fuel_Type               1276 non-null   object
#  10  Body_Type               1276 non-null   object
#  11  Doors                   1276 non-null   float64
#  12  ARAI_Certified_Mileage  1276 non-null   float64
#  13  Gears                   1276 non-null   object
# ...

# %%
# Doing univariate and bivariate analysis

# %%
sns.distplot(df['Ex-Showroom_Price'])
#data is skewed or we can say that there are more cars who's price range is on lower side
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Ex-Showroom_Price', ylabel='Density'>

# %%
df['Make'].value_counts().plot(kind='bar', figsize=(20,10))
# we can say that Maruti Suzuki manufactures maximum number of cars
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df['Make'], y=df['Ex-Showroom_Price'])
plt.xticks(rotation='vertical')
plt.show()
# Lamborghini, Bentley, Ferrari, Aston Martin, Rolls-Royce and Buggati are some of the most expensive and Luxurious cars

# %%
with plt.rc_context(dict(sns.axes_style("whitegrid"),
                     **sns.plotting_context(font_scale=15))):
    sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.boxplot(x=df['Make'], y=df['Ex-Showroom_Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Body_Type'].value_counts().plot(kind='bar', figsize=(15,7.5))
# most of the cars in the dataset are SUV succeeding by Sedan
# Out:
# <AxesSubplot:>

# %%
df['Fuel_Type'].value_counts().plot(kind='bar')
# Petrol and Diesel are the most common Fuel types
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df['Fuel_Type'], y=df['Ex-Showroom_Price'])
plt.xticks(rotation='vertical')
plt.show()
# Cars with Hybrid fuel type are tend to be more expensive as compared to that of petrol/diesel

# %%
df['Model'].value_counts()
# df[df['Model'].value_counts()>10]
# Out:
# Nexon                                24
# Kuv100 Nxt                           22
# Compass                              21
# Xuv500                               21
# Amaze                                20
# Creta                                18
# Seltos                               16
# Innova Crysta                        16
# Ciaz                                 14
# Swift                                14
# Yaris                                14
# Rapid                                14
# Dzire                                14
# Wagon                                14
# Etios Liva                           14
# Venue                                13
# Verna                                13
# Aspire                               13
# Baleno                               13
# Octavia                              12
# Vento                                12
# Elite I20                            12
# Aura                                 12
# ...

# %%
df['Make'].value_counts()
# Out:
# Maruti Suzuki    163
# Hyundai          130
# Mahindra         119
# Tata             100
# Toyota            82
# Honda             64
# Mercedes          57
# Skoda             43
# Ford              43
# Land Rover        37
# Bmw               37
# Renault           36
# Volkswagen        34
# Audi              31
# Nissan            29
# Jeep              28
# Kia               27
# Datsun            24
# Fiat              23
# Jaguar            22
# Volvo             18
# Porsche           14
# Mg                13
# Lamborghini       13
# Icml              11
# Mini              10
# Lexus             10
# Maserati           9
# Rolls-Royce        9
# Ferrari            8
# Mitsubishi         7
# Bentley            6
# Force              6
# Isuzu              5
# Aston Martin       3
# Bugatti            2
# Bajaj              2
# Dc                 1
# Name: Make, dtype: int64

# %%
sns.distplot(df['ARAI_Certified_Mileage'])
# There are some outliers in ARAI Certified Mileage therefore the graph stretched to 1400
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='ARAI_Certified_Mileage', ylabel='Density'>

# %%
sns.scatterplot(x=df['ARAI_Certified_Mileage'], y=df['Ex-Showroom_Price'])
# here the outliers are clearly visible
# Out:
# <AxesSubplot:xlabel='ARAI_Certified_Mileage', ylabel='Ex-Showroom_Price'>

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Variant', 'Ex-Showroom_Price', 'Displacement',
#        'Kerb_Weight', 'Cylinders', 'Emission_Norm', 'Fuel_Tank_Capacity',
#        'Fuel_Type', 'Body_Type', 'Doors', 'ARAI_Certified_Mileage', 'Gears',
#        'Ground_Clearance', 'Power', 'Torque', 'Type', 'Odometer',
#        'Speedometer', 'Tachometer', 'Seating_Capacity', 'Start_/_Stop_Button',
#        'Audiosystem', 'Aux-in_Compatibility', 'Basic_Warranty', 'Bluetooth',
#        '12v_Power_Outlet', 'Boot-lid_Opener', 'Boot_Space',
#        'Child_Safety_Locks', 'Extended_Warranty', 'Fuel-lid_Opener',
#        'Fuel_Gauge', 'Handbrake', 'Hill_Assist', 'Airbags',
#        'Number_of_Airbags', 'Parking_Assistance', 'Infotainment_Screen',
#        'Navigation_System', 'Third_Row_AC_Vents', 'Second_Row_AC_Vents',
#        'Engine_Type', 'Rain_Sensing_Wipers'],
#       dtype='object')

# %%
df['Seating_Capacity'].value_counts().plot(kind='bar')
# most of the cars i.e SUV's and Sedan are 5 seaters
# Out:
# <AxesSubplot:>

# %%
df['Child_Safety_Locks'].value_counts().plot(kind='bar')
# most of the cars have child safety locks
# Out:
# <AxesSubplot:>

# %%
df['Number_of_Airbags'].value_counts().plot(kind='bar')
# more then 600 cars have 2 airbags followed by 6 airbags for occupants safety
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df['Number_of_Airbags'], y=df['Ex-Showroom_Price'])
# cars with 2 airbags are lower priced as compared to 6 airbags. As Ex-showroom price increases, these cars will have more features like airbags, more comfortable and spacious
# Out:
# <AxesSubplot:xlabel='Number_of_Airbags', ylabel='Ex-Showroom_Price'>

# %%
df.corr()['Ex-Showroom_Price']
# ARAI certified mileage, Ground clearance, boot space have no or negligible relation with ex-showroom price, these features have no impact on car price
# Out:
# Ex-Showroom_Price         1.000000
# Displacement              0.794536
# Kerb_Weight               0.414959
# Cylinders                 0.787036
# Fuel_Tank_Capacity        0.550802
# Doors                    -0.460311
# ARAI_Certified_Mileage   -0.040224
# Ground_Clearance         -0.088507
# Seating_Capacity         -0.307150
# Boot_Space                0.055223
# Number_of_Airbags         0.323961
# Name: Ex-Showroom_Price, dtype: float64

# %%
print(df['Basic_Warranty'].unique())
# Out:
# ['2 years /75000 Kms ' '2 years without mileage limit'
#  '2 years /50000 Kms ' '2 years /40000 Kms ' '3 years /100000 Kms '
#  '2 years /100000 Kms ' '3 years without mileage limit'
#  '3 years /40000 Kms ' '4 years /80000 Kms '
#  '4 years without mileage limit' '3 years /60000 Kms '
#  '1 year without mileage limit' '8 years /160000 kms ']

# %%
sns.barplot(x=df['Basic_Warranty'], y=df['Ex-Showroom_Price'])
plt.xticks(rotation='vertical')
plt.show()
# By looking at the graph, we can say that generally cars get 4 years basic warranty

# %%
print(df['Extended_Warranty'].unique())
# Out:
# ['2 years /150000 Kms ' '2 Years Unlimited Kilometres'
#  '3rd/4th year/up to 80,000 Kms ' '2 years + 1 year '
#  '2 years /80000 Kms ' '3 years /150000 Kms '
#  '3rd /4th Years / up to 1,00,000 Kms ' '2 years /100000 Kms '
#  '3 Years /75000 Kms ' '1 years /20000 Kms ' '3rd/4th year'
#  '4th year /with ' '3 Years /100000 Kms '
#  '12/24 months /up to 100000 Kms ' '12/24 months /up to 200000 Kms '
#  '1 Years Unlimited Kilometres' '12/24 months /up to 90000 Kms '
#  'Up to 5 Year /' '1 years /30000 Kms ' '3 Years Unlimited Kilometres'
#  '4 years /100000 Kms ' '4 years /120000 Kms ' '4 years /150000 Kms '
#  '12/24 months and can be renewed or extended for a further period']

# %%
sns.barplot(x=df['Extended_Warranty'], y=df['Ex-Showroom_Price'])
plt.xticks(rotation='vertical')
plt.show()
# people generally get their warranty extended by 1/2 years

# %%
sns.scatterplot(x=df['Kerb_Weight'], y=df['Ex-Showroom_Price'])
# do not have any relation with ex-showroom price
# Out:
# <AxesSubplot:xlabel='Kerb_Weight', ylabel='Ex-Showroom_Price'>

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# We will be further analyzing cars which are more on affordable side

# %%
df1= df[df['Ex-Showroom_Price']<1500000]

# %%
df1.shape
# Out:
# (805, 45)

# %%
df1['Make'].value_counts().plot(kind='bar', figsize=(20,10))
# Manufacturers other than these make high-end cars
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=df1['Make'], y=df1['Ex-Showroom_Price'])
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ## Safety Features

# %% [markdown]
# Start_/Stop_Button, Handbrake, Hill_Assist, Child_Safety_Lock, Number_of_Airbags, Rain_Sensing_Wipers, Airbags, Parking_Assistance are the features that play a major role in safety of people in the car. These features may help help in preventing accidents,life loses and minimizing car damage

# %%
sns.boxplot(x=df1['Start_/_Stop_Button'], y=df1['Ex-Showroom_Price'])
plt.xticks(rotation='vertical')
plt.show()
# cars with Start/stop button are more expensive

# %%
# df1['Start_/_Stop_Button'].value_counts().plot(kind='bar')
sns.countplot(x='Start_/_Stop_Button', data=df1, palette='ocean')
plt.show()
# but almost 600 cars donot have start/stop button

# %%
sns.barplot(x='Make', y='Ex-Showroom_Price', hue='Start_/_Stop_Button',data=df1, palette='pink')
plt.xticks(rotation='vertical')
plt.show()
# datsun, bajaj, icml, force, skoda and mg manufacturers donot make cars with start/stop button

# %%
sns.boxplot(x=df1['Handbrake'], y=df1['Ex-Showroom_Price'])
plt.xticks(rotation='vertical')
plt.show()
# handbrake do not affetc car price

# %%
sns.countplot(x='Handbrake', data=df1, palette='ocean')
plt.show()
# almost every car has manual handbrake

# %%
sns.barplot(x='Make', y='Ex-Showroom_Price', hue='Handbrake',data=df1, palette='prism')
plt.xticks(rotation='vertical')
plt.show()
# hyundai, kia, mahindra and fiat manufactures cars with automatic handbrake

# %%
sns.boxplot(x=df1['Hill_Assist'], y=df1['Ex-Showroom_Price'])
plt.xticks(rotation='vertical')
plt.show()
# Hill assist is present in more expensive cars as compared to low priced cars

# %%
sns.countplot(x='Hill_Assist', data=df1, palette='ocean_r')
plt.show()
# around approx 100 cars in this category dataset have hill assist

# %%
sns.barplot(x='Make', y='Ex-Showroom_Price', hue='Hill_Assist',data=df1, palette='plasma')
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.boxplot(x=df1['Child_Safety_Locks'], y=df1['Ex-Showroom_Price'])
plt.xticks(rotation='vertical')
plt.show()
# child safety lock donot any have any direct or indirect relationship with ex-showroom price

# %%
sns.countplot(x='Child_Safety_Locks', data=df1, palette='ocean_r')
plt.show()
# almost every car has this feature

# %%
sns.barplot(x='Make', y='Ex-Showroom_Price', hue='Child_Safety_Locks',data=df1, palette='plasma_r')
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.boxplot(x=df1['Rain_Sensing_Wipers'], y=df1['Ex-Showroom_Price'])
plt.xticks(rotation='vertical')
plt.show()
# low-end cars donot have rain sensing wipers

# %%
sns.countplot(x='Rain_Sensing_Wipers', data=df1, palette='ocean_r')
plt.show()
# less number of cars have this feature incorporated

# %%
sns.barplot(x='Make', y='Ex-Showroom_Price', hue='Hill_Assist',data=df1, palette='plasma_r')
plt.xticks(rotation='vertical')
plt.show()

# %%
df1['Parking_Assistance']=df1['Parking_Assistance'].replace('Yes', np.nan)
df1['Parking_Assistance']=df1['Parking_Assistance'].fillna(method='ffill')
df1['Parking_Assistance']=df1['Parking_Assistance'].replace('Rear sensors, Rear sensors with camera','Rear sensors with camera, Rear sensors')
df1['Parking_Assistance']=df1['Parking_Assistance'].replace('Rear sensors, Front sensors', 'Front sensors, Rear sensors')
sns.boxplot(x=df1['Parking_Assistance'], y=df1['Ex-Showroom_Price'])
plt.xticks(rotation='vertical')
plt.show()
# we cannot comment upon parking assistance
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_4488\3870475796.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Parking_Assistance']=df1['Parking_Assistance'].replace('Yes', np.nan)
# C:\Users\user\AppData\Local\Temp\ipykernel_4488\3870475796.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Parking_Assistance']=df1['Parking_Assistance'].fillna(method='ffill')
# C:\Users\user\AppData\Local\Temp\ipykernel_4488\3870475796.py:3: SettingWithCopyWarning:
# ...

# %%
sns.countplot(x='Parking_Assistance', data=df1, palette='ocean_r')
plt.xticks(rotation='vertical')
plt.show()
# many cars donot have parking assistance and if it is presnt than either they have rear sensors or rear sensors with camera

# %%
sns.boxplot(x=df1['Number_of_Airbags'], y=df1['Ex-Showroom_Price'])
plt.xticks(rotation='vertical')
plt.show()
# as number of airbags increases, car price definitely increases

# %%
sns.countplot(x='Number_of_Airbags', data=df1, palette='ocean_r')
plt.show()
# maximum cars have 2 airbags at positions Driver frontal airbag, Front passenger frontal airbag

# %%
dfd = df1[df1['Number_of_Airbags']==2]
dfd['Airbags'].value_counts()
# Out:
# Driver frontal airbag, Front passenger frontal airbag                                                    523
# Front passenger frontal airbag, Driver frontal airbag                                                     39
# Driver frontal airbag                                                                                      4
# Front passenger frontal airbag                                                                             2
# Driver frontal airbag, Front passenger frontal airbag, Front passenger side airbag, Drive side airbag      1
# Driver frontal airbag, Front passenger side airbag                                                         1
# Name: Airbags, dtype: int64

# %% [markdown]
# ## Common car combination specification

# %%
df1.describe(include='all')
# Out:
#                  Make  Model Variant  Ex-Showroom_Price  Displacement  \
# count             805    805     805       8.050000e+02    805.000000
# unique             18    111     655                NaN           NaN
# top     Maruti Suzuki  Nexon     Lxi                NaN           NaN
# freq              163     24       9                NaN           NaN
# mean              NaN    NaN     NaN       8.383709e+05   1348.899689
# std               NaN    NaN     NaN       2.806507e+05    331.986178
# min               NaN    NaN     NaN       2.364470e+05     72.000000
# 25%               NaN    NaN     NaN       6.300000e+05   1197.000000
# 50%               NaN    NaN     NaN       8.085580e+05   1248.000000
# 75%               NaN    NaN     NaN       9.999000e+05   1497.000000
# max               NaN    NaN     NaN       1.499000e+06   2755.000000
#
#         Kerb_Weight   Cylinders Emission_Norm  Fuel_Tank_Capacity Fuel_Type  \
# ...

# %%
sns.pairplot(df1)

# %%
df1.mode(axis=0, numeric_only=False)
# Out:
#             Make  Model Variant  Ex-Showroom_Price  Displacement  Kerb_Weight  \
# 0  Maruti Suzuki  Nexon     Lxi           999900.0        1197.0        985.0
# 1            NaN    NaN     Vxi                NaN           NaN          NaN
#
#    Cylinders Emission_Norm  Fuel_Tank_Capacity Fuel_Type  Body_Type  Doors  \
# 0        4.0         BS IV                45.0    Petrol  Hatchback    5.0
# 1        NaN           NaN                 NaN       NaN        NaN    NaN
#
#    ARAI_Certified_Mileage Gears  Ground_Clearance         Power  \
# 0                    23.0     5             165.0  83PS@6000rpm
# 1                     NaN   NaN               NaN           NaN
#
#           Torque    Type Odometer Speedometer Tachometer  Seating_Capacity  \
# 0  200Nm@1750rpm  Manual  Digital      Analog     Analog               5.0
# 1   90Nm@3500rpm     NaN      NaN         NaN        NaN               NaN
#
#   Start_/_Stop_Button                  Audiosystem Aux-in_Compatibility  \
# ...

# %%
df1['Make'].value_counts()
# taken dataframe with top 5 manufacturers
# Out:
# Maruti Suzuki    163
# Hyundai          114
# Mahindra          97
# Tata              88
# Honda             55
# Toyota            51
# Ford              39
# Renault           36
# Nissan            28
# Volkswagen        28
# Datsun            24
# Fiat              23
# Skoda             18
# Kia               17
# Icml              10
# Force              6
# Mg                 6
# Bajaj              2
# Name: Make, dtype: int64

# %%
df2 = df1[df1['Make']=='Maruti Suzuki']
df3 = df2.append(df1[df1['Make']=='Hyundai'])
df4 = df3.append(df1[df1['Make']=='Mahindra'])
df5 = df4.append(df1[df1['Make']=='Tata'])
df6 = df5.append(df1[df1['Make']=='Honda'])
df7 = df6.append(df1[df1['Make']=='Toyota'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_4488\870820206.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df3 = df2.append(df1[df1['Make']=='Hyundai'])
# C:\Users\user\AppData\Local\Temp\ipykernel_4488\870820206.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df4 = df3.append(df1[df1['Make']=='Mahindra'])
# C:\Users\user\AppData\Local\Temp\ipykernel_4488\870820206.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df5 = df4.append(df1[df1['Make']=='Tata'])
# C:\Users\user\AppData\Local\Temp\ipykernel_4488\870820206.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df6 = df5.append(df1[df1['Make']=='Honda'])
# ...

# %%
df7.sample(5)
# Out:
#                Make       Model                   Variant  Ex-Showroom_Price  \
# 1090  Maruti Suzuki        Ciaz   1.3L Sigma Smart Hybrid           919689.0
# 397        Mahindra  Kuv100 Nxt                K2+ D 6Str           619243.0
# 946           Honda        Wr-V  Exclusive Edition Diesel          1048050.0
# 1174  Maruti Suzuki       Wagon                   Vxi Ags           526000.0
# 909   Maruti Suzuki      Baleno                  1.2 Zeta           697912.0
#
#       Displacement  Kerb_Weight  Cylinders Emission_Norm  Fuel_Tank_Capacity  \
# 1090        1248.0       1105.0        4.0         BS IV                43.0
# 397         1198.0        935.0        3.0         BS IV                35.0
# 946         1498.0       1204.0        4.0         BS IV                40.0
# 1174         998.0       1525.0        3.0          BS 6                32.0
# 909         1197.0        880.0        4.0          BS 6                37.0
#
# ...

# %%
df1.mode(axis=0, numeric_only=False)
# these are the most common car features/specifications
# Out:
#             Make  Model Variant  Ex-Showroom_Price  Displacement  Kerb_Weight  \
# 0  Maruti Suzuki  Nexon     Lxi           999900.0        1197.0        985.0
# 1            NaN    NaN     Vxi                NaN           NaN          NaN
#
#    Cylinders Emission_Norm  Fuel_Tank_Capacity Fuel_Type  Body_Type  Doors  \
# 0        4.0         BS IV                45.0    Petrol  Hatchback    5.0
# 1        NaN           NaN                 NaN       NaN        NaN    NaN
#
#    ARAI_Certified_Mileage Gears  Ground_Clearance         Power  \
# 0                    23.0     5             165.0  83PS@6000rpm
# 1                     NaN   NaN               NaN           NaN
#
#           Torque    Type Odometer Speedometer Tachometer  Seating_Capacity  \
# 0  200Nm@1750rpm  Manual  Digital      Analog     Analog               5.0
# 1   90Nm@3500rpm     NaN      NaN         NaN        NaN               NaN
#
#   Start_/_Stop_Button                  Audiosystem Aux-in_Compatibility  \
# ...

# %%
df7.mode(axis=0, numeric_only=False)
# Out:
#             Make  Model Variant  Ex-Showroom_Price  Displacement  Kerb_Weight  \
# 0  Maruti Suzuki  Nexon     Lxi           999900.0        1197.0        985.0
# 1            NaN    NaN     Vxi                NaN           NaN          NaN
#
#    Cylinders Emission_Norm  Fuel_Tank_Capacity Fuel_Type  Body_Type  Doors  \
# 0        4.0         BS IV                35.0    Petrol  Hatchback    5.0
# 1        NaN           NaN                 NaN       NaN        NaN    NaN
#
#    ARAI_Certified_Mileage Gears  Ground_Clearance         Power        Torque  \
# 0                    23.1     5             165.0  83PS@6000rpm  90Nm@3500rpm
# 1                     NaN   NaN               NaN           NaN           NaN
#
#      Type Odometer Speedometer Tachometer  Seating_Capacity  \
# 0  Manual  Digital      Analog     Analog               5.0
# 1     NaN      NaN         NaN        NaN               NaN
#
#   Start_/_Stop_Button                  Audiosystem Aux-in_Compatibility  \
# ...

# %%
# comparing df1 and df7 only difference between fuel tank capacity,ARAI_Certified_Mileage
# fuel tank capacity 35 and 42 both very common capacities
# arai certified mileage only deferred by 0.1 that hardly affects

# %%
print('for df1', df1['Fuel_Tank_Capacity'].value_counts())
print('for df7', df7['Fuel_Tank_Capacity'].value_counts())
# Out:
# for df1 45.0     132
# 35.0     124
# 37.0      79
# 40.0      54
# 50.0      53
# 42.0      51
# 55.0      51
# 60.0      49
# 44.0      43
# 43.0      41
# 32.0      21
# 28.0      18
# 63.0      17
# 41.0      14
# 48.0      13
# 52.0      12
# 27.0      10
# 70.0       6
# 46.0       6
# 24.0       5
# 100.0      2
# 80.0       2
# 15.0       1
# 36.0       1
# Name: Fuel_Tank_Capacity, dtype: int64
# for df7 35.0    106
# 45.0     92
# 37.0     79
# 44.0     43
# 43.0     41
# 60.0     39
# 40.0     38
# 42.0     36
# 55.0     22
# 32.0     21
# 48.0     13
# 27.0     10
# 50.0      8
# 70.0      6
# 24.0      5
# 63.0      5
# 80.0      2
# 15.0      1
# 36.0      1
# Name: Fuel_Tank_Capacity, dtype: int64
